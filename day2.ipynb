# %% [markdown]
# 변수 선언

# %%
watch=100000
a='pig'
b='dad'
print(a)
print(b)
print(watch)
# Out:
# pig
# dad
# 100000

# %% [markdown]
# 여러 개의 변수를 선언 하는 방법

# %%
a=10#자동선언
a,b=(10,20)#튜플 활용
[a,b]=[10,20]#List 활용
a=b=10#a,b같은값 할당
a=None#비어있는 변수

# %% [markdown]
# 변수 사용법

# %%
#교환
a=10
b=2000
a,b=b,a

# %%
#List 사용법(C에서는 배열)
a=[10, 20, 30]
b=a

a[0] = 200#List의 첫번째열을 200으로 변경
print(b)
# Out:
# [200, 20, 30]

# %% [markdown]
# print

# %%
print("Hello World")
print('Hello World')
print(1)
print("1")
# Out:
# Hello World
# Hello World
# 1
# 1

# %%
a=10
print("a="+str(a))#정수를 string으로 변환
print("a=",a)
print("a={}".format(a))
# Out:
# a=10
# a= 10
# a=10

# %% [markdown]
# print문 사용법 실습

# %%
A=[10,20,30]
B=1
C=2

print(A)
print("A={}",format(A))
print("B={}",format(B))
print("A={}, B={}, C={}".format(A[0],B,C))
# Out:
# [10, 20, 30]
# A={} [10, 20, 30]
# B={} 1
# A=10, B=1, C=2
